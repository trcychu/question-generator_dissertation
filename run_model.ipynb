# %%
# split the data into training and validation set, and write each row in validation set into a text file.
texts = []
questions = []
for idx, row in data.iterrows():
    texts.append(row['context'].strip())
    questions.append(row['questions'].strip())
train_texts, val_texts, train_questions, val_questions = train_test_split(
    texts, questions, test_size=0.1, random_state=2)

for i in range(0,len(val_texts)):
    text=str(val_texts[i])
    path='val_data/'+str(i)+".txt" # write it into the .txt file
    with open(path, 'w') as f:
        f.write(text)

# %%
# fine tuned bart model, predict on validation dataset
# !python 'qg_tuned/question_generator_tuned/question_generator/run_qg.py' --text_dir "val_data/" --output_file 'result_bart_tune_val.csv' --num_questions=1 --answer_style sentences
# Out:
#          .:::.     .::.
#         ....yy:    .yy.
#         :.  .yy.    y.
#              :y:   .:
#              .yy  .:
#               yy..:
#               :y:.
#               .y.
#              .:.
#         ....:.
#         :::.
#
# • Project files and data should be stored in /project. This is shared among everyone
#   in the project.
# • Personal files and configuration should be stored in /home/faculty.
# • Files outside /project and /home/faculty will be lost when this server is terminated.
# • Create custom environments to setup your servers reproducibly.
#
# 2021-08-15 17:13:37.326634: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory
# 2021-08-15 17:13:37.326675: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Generating questions...
#
# ...

# %%
# fine tuned t5 model, predict on validation dataset

# !python 'question_generator_tuned/question_generator/run_qg.py' --text_dir "val_data/" --output_file 'result_t5_tune_val.csv' --num_questions=1 --answer_style sentences
# Out:
#          .:::.     .::.
#         ....yy:    .yy.
#         :.  .yy.    y.
#              :y:   .:
#              .yy  .:
#               yy..:
#               :y:.
#               .y.
#              .:.
#         ....:.
#         :::.
#
# • Project files and data should be stored in /project. This is shared among everyone
#   in the project.
# • Personal files and configuration should be stored in /home/faculty.
# • Files outside /project and /home/faculty will be lost when this server is terminated.
# • Create custom environments to setup your servers reproducibly.
#
# 2021-08-15 17:47:11.234202: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory
# 2021-08-15 17:47:11.234246: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Generating questions...
#
# ...

# %%
# before fine tune t5 model, predict on validation set
# !python 'question_generator_tuned/question_generator/run_qg.py' --text_dir "val_data/" --output_file 'result_t5_tune_val.csv' --num_questions=1 --answer_style sentences
# Out:
#          .:::.     .::.
#         ....yy:    .yy.
#         :.  .yy.    y.
#              :y:   .:
#              .yy  .:
#               yy..:
#               :y:.
#               .y.
#              .:.
#         ....:.
#         :::.
#
# • Project files and data should be stored in /project. This is shared among everyone
#   in the project.
# • Personal files and configuration should be stored in /home/faculty.
# • Files outside /project and /home/faculty will be lost when this server is terminated.
# • Create custom environments to setup your servers reproducibly.
#
# 2021-08-15 17:14:34.083290: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory
# 2021-08-15 17:14:34.083337: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# ...

# %%
# before fine tune bart model, predict on validation set

# !python 'bart_before/question_generator/run_qg.py' --text_dir "data_val/" --output_file 'result_bart_before.csv' --num_questions=1 --answer_style="sentences"
# Out:
#          .:::.     .::.
#         ....yy:    .yy.
#         :.  .yy.    y.
#              :y:   .:
#              .yy  .:
#               yy..:
#               :y:.
#               .y.
#              .:.
#         ....:.
#         :::.
#
# • Project files and data should be stored in /project. This is shared among everyone
#   in the project.
# • Personal files and configuration should be stored in /home/faculty.
# • Files outside /project and /home/faculty will be lost when this server is terminated.
# • Create custom environments to setup your servers reproducibly.
#
# 2021-08-13 03:18:02.463825: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory
# 2021-08-13 03:18:02.463868: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# ...
